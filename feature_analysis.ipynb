# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('../Boats_Cleaned_dataset.csv')
df = df.dropna()
df.shape
# Out:
# (1074, 26)

# %%
df = df.drop(columns=['#', 'id', 'created_date', 'sellerId', 'zip', 'city', 'state', 'created_month', 'created_year', 'engineCategory', 'hullMaterial', 'fuelType', 'model', 'make'])
df.head()
# Out:
#      type           boatClass  year condition  length_ft  beam_ft  \
# 1   power  power-sportcruiser  2018      used       40.0    11.00
# 2   power          power-deck  2020       new       18.0     7.42
# 4   power           power-aft  1994      used       44.0    15.00
# 9   power   power-convertible  1971      used       42.0    13.83
# 10  power   power-convertible  1979      used       43.0    14.50
#
#     dryWeight_lb  numEngines  totalHP  maxEngineYear  minEngineYear     price
# 1        16100.0           2    800.0         2018.0         2018.0  539000.0
# 2         2000.0           1     75.0         2019.0         2019.0   26995.0
# 4        32000.0           2    700.0         1994.0         1994.0  109900.0
# 9        35400.0           2    840.0         1977.0         1977.0   59500.0
# 10       41000.0           2    900.0         1979.0         1979.0   79500.0

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
stnd = StandardScaler().set_output(transform='pandas')
df = stnd.fit_transform(df)

# %%
n_samples = 1000

lr = LinearRegression()
cols = df.drop('price', axis=1).columns
coef = pd.DataFrame(index=cols, columns=range(n_samples))
for k in range(n_samples):
    df_b = df.sample(frac=1.0, replace=True)
    X = df_b.drop('price', axis=1)
    y = df_b.price
    lr.fit(X,y)
    coef.iloc[:,k] = lr.coef_

# %%
quantiles = coef.quantile([0.05,0.95],axis=1).T.round(3)
quantiles
# Out:
#                                                 0.05                  0.95
# year                                        0.107771              0.263958
# length_ft                                   0.082641                 0.511
# beam_ft                                    -0.388053             -0.005067
# dryWeight_lb                                0.172659              0.705009
# numEngines                                  0.104473              0.245982
# totalHP                                     0.075231              0.245072
# maxEngineYear                              -0.429415             -0.077508
# minEngineYear                               0.333313              0.746924
# type_sail                      -2449175548552.308105  2120629692528.742676
# boatClass_power-aluminum                   -0.024626              0.097382
# boatClass_power-antique         -239305112467.155457   255776881136.580505
# boatClass_power-bass                       -0.018329              0.138514
# boatClass_power-bay                        -0.023613              0.084117
# boatClass_power-bowrider                   -0.028942              0.125739
# boatClass_power-center                     -0.003545              0.254501
# boatClass_power-convertible                -0.052486              0.034222
# boatClass_power-cruiser                    -0.027752              0.142717
# boatClass_power-cuddy                       0.027642               0.09503
# boatClass_power-deck                       -0.002764               0.08984
# boatClass_power-downeast                   -0.006391              0.047884
# boatClass_power-dualconsole                -0.008848              0.072261
# boatClass_power-expresscruiser             -0.051354              0.065775
# boatClass_power-flats             -8759477485.868578    17543393878.045296
# boatClass_power-flybridge                    0.01074              0.196046
# boatClass_power-fresh                       -0.00707              0.066163
# boatClass_power-highperf                   -0.026187              0.072235
# boatClass_power-house                      -0.087534             -0.001864
# boatClass_power-jet                        -0.031905               0.03786
# boatClass_power-jon                        -0.028627              0.063414
# boatClass_power-lobster           -2995596183.287107     2357141846.446907
# boatClass_power-motor                      -0.067456              0.108361
# boatClass_power-other            -14131757293.894278    12290975673.135237
# boatClass_power-pcatamaran                 -0.014943              0.068268
# boatClass_power-pilot                       0.007933              0.324988
# boatClass_power-pontoon                     -0.06245              0.128954
# boatClass_power-pwc                        -0.023947               0.08107
# boatClass_power-rib                        -0.004411              0.038932
# boatClass_power-runabout                    0.005173              0.116092
# boatClass_power-saltfish                   -0.026859              0.110525
# boatClass_power-skiff                      -0.012696              0.040741
# boatClass_power-skifish                    -0.014004              0.033159
# boatClass_power-skiwake                    -0.001939              0.122354
# boatClass_power-sportcruiser               -0.018859              0.057032
# boatClass_power-sportfish                  -0.026727              0.087907
# boatClass_power-tender                      0.001214              0.075291
# boatClass_power-trawler                      0.01877               0.08735
# boatClass_power-tug                        -0.046513              0.033113
# boatClass_power-unspec                     -0.005808              0.033395
# boatClass_power-util                       -0.006441               0.05283
# boatClass_power-walk                        0.008277              0.081776
# boatClass_sail-catamaran           -338862766122.862   431716633909.701843
# boatClass_sail-cruiser         -1568895205119.015381  1811961696167.979004
# boatClass_sail-day              -305594738646.402527   438294787419.306152
# boatClass_sail-racer            -337143508125.398254   399305158489.870667
# boatClass_sail-racercruiser      -713324997423.71228   872562766372.155396
# boatClass_sail-sloop            -873949729160.894165  1009349399787.279785
# boatClass_sail-unspec           -345024887338.789795   355665811513.477173
# condition_used                              -0.00489              0.074993

# %%
quantiles[
    (quantiles[0.05] > 0) & (quantiles[0.95] > 0) | 
    (quantiles[0.05] < 0) & (quantiles[0.95] < 0)
]
# Out:
#                                0.05      0.95
# year                       0.107771  0.263958
# length_ft                  0.082641     0.511
# beam_ft                   -0.388053 -0.005067
# dryWeight_lb               0.172659  0.705009
# numEngines                 0.104473  0.245982
# totalHP                    0.075231  0.245072
# maxEngineYear             -0.429415 -0.077508
# minEngineYear              0.333313  0.746924
# boatClass_power-cuddy      0.027642   0.09503
# boatClass_power-flybridge   0.01074  0.196046
# boatClass_power-house     -0.087534 -0.001864
# boatClass_power-pilot      0.007933  0.324988
# boatClass_power-runabout   0.005173  0.116092
# boatClass_power-tender     0.001214  0.075291
# boatClass_power-trawler     0.01877   0.08735
# boatClass_power-walk       0.008277  0.081776

# %% [markdown]
# year, length, dryWEight, numEngines, totalHp, maxEngineYear, minEngineYear, boatClass
